# %%
pip install selenium beautifulsoup4 pandas openpyxl webdriver-manager
# Out:
# Requirement already satisfied: selenium in c:\users\sansk\anaconda3\lib\site-packages (4.34.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\sansk\anaconda3\lib\site-packages (4.12.3)
# Requirement already satisfied: pandas in c:\users\sansk\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: openpyxl in c:\users\sansk\anaconda3\lib\site-packages (3.1.5)
# Collecting webdriver-manager
#   Downloading webdriver_manager-4.0.2-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: urllib3~=2.5.0 in c:\users\sansk\anaconda3\lib\site-packages (from urllib3[socks]~=2.5.0->selenium) (2.5.0)
# Requirement already satisfied: trio~=0.30.0 in c:\users\sansk\anaconda3\lib\site-packages (from selenium) (0.30.0)
# Requirement already satisfied: trio-websocket~=0.12.2 in c:\users\sansk\anaconda3\lib\site-packages (from selenium) (0.12.2)
# Requirement already satisfied: certifi>=2025.6.15 in c:\users\sansk\anaconda3\lib\site-packages (from selenium) (2025.7.14)
# Requirement already satisfied: typing_extensions~=4.14.0 in c:\users\sansk\anaconda3\lib\site-packages (from selenium) (4.14.1)
# Requirement already satisfied: websocket-client~=1.8.0 in c:\users\sansk\anaconda3\lib\site-packages (from selenium) (1.8.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\sansk\anaconda3\lib\site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\sansk\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sansk\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sansk\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sansk\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: et-xmlfile in c:\users\sansk\anaconda3\lib\site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: requests in c:\users\sansk\anaconda3\lib\site-packages (from webdriver-manager) (2.32.3)
# Requirement already satisfied: python-dotenv in c:\users\sansk\anaconda3\lib\site-packages (from webdriver-manager) (0.21.0)
# Requirement already satisfied: packaging in c:\users\sansk\anaconda3\lib\site-packages (from webdriver-manager) (24.1)
# Requirement already satisfied: six>=1.5 in c:\users\sansk\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\sansk\anaconda3\lib\site-packages (from trio~=0.30.0->selenium) (25.3.0)
# Requirement already satisfied: sortedcontainers in c:\users\sansk\anaconda3\lib\site-packages (from trio~=0.30.0->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\sansk\anaconda3\lib\site-packages (from trio~=0.30.0->selenium) (3.7)
# Requirement already satisfied: outcome in c:\users\sansk\anaconda3\lib\site-packages (from trio~=0.30.0->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\sansk\anaconda3\lib\site-packages (from trio~=0.30.0->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\sansk\anaconda3\lib\site-packages (from trio~=0.30.0->selenium) (1.17.1)
# Requirement already satisfied: wsproto>=0.14 in c:\users\sansk\anaconda3\lib\site-packages (from trio-websocket~=0.12.2->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\sansk\anaconda3\lib\site-packages (from urllib3[socks]~=2.5.0->selenium) (1.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sansk\anaconda3\lib\site-packages (from requests->webdriver-manager) (3.3.2)
# Requirement already satisfied: pycparser in c:\users\sansk\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.30.0->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\sansk\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.12.2->selenium) (0.14.0)
# Downloading webdriver_manager-4.0.2-py2.py3-none-any.whl (27 kB)
# Installing collected packages: webdriver-manager
# Successfully installed webdriver-manager-4.0.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup

# === Step 1: Read Excel file ===
input_file = "Input.xlsx"
df = pd.read_excel(input_file)

# === Step 2: Setup Selenium WebDriver ===
chrome_options = Options()
chrome_options.add_argument("--headless")   # run in background (no browser window)
chrome_options.add_argument("--disable-gpu")
chrome_options.add_argument("--no-sandbox")
chrome_options.add_argument("--window-size=1920,1080")

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)

# === Step 3: Create output folder ===
output_folder = "articles"
os.makedirs(output_folder, exist_ok=True)

# === Step 4: Function to scrape article ===
def extract_article_with_selenium(url):
    try:
        driver.get(url)
        time.sleep(2)  # wait for page to load fully

        soup = BeautifulSoup(driver.page_source, "html.parser")

        # Extract article title (try <h1> first, fallback to <title>)
        title_tag = soup.find("h1") or soup.find("title")
        title = title_tag.get_text(strip=True) if title_tag else "No Title Found"

        # Extract article content (all <p> tags)
        paragraphs = soup.find_all("p")
        article_text = "\n".join(p.get_text(strip=True) for p in paragraphs if p.get_text(strip=True))

        return title, article_text
    except Exception as e:
        print(f"❌ Error extracting {url}: {e}")
        return None, None

# === Step 5: Loop through URLs and save to .txt files ===
for _, row in df.iterrows():
    url_id = str(row["URL_ID"])
    url = row["URL"]

    print(f"Scraping: {url}")
    title, content = extract_article_with_selenium(url)

    if title and content:
        file_path = os.path.join(output_folder, f"{url_id}.txt")
        with open(file_path, "w", encoding="utf-8") as f:
            f.write(title + "\n\n" + content)
        print(f"✅ Saved: {file_path}")
    else:
        print(f"⚠️ Skipped: {url} (no content extracted)")

# === Step 6: Close driver ===
driver.quit()
# Out:
# Scraping: https://insights.blackcoffer.com/ai-and-ml-based-youtube-analytics-and-content-creation-tool-for-optimizing-subscriber-engagement-and-content-strategy/
# ✅ Saved: articles\Netclan20241017.txt
# Scraping: https://insights.blackcoffer.com/enhancing-front-end-features-and-functionality-for-improved-user-experience-and-dashboard-accuracy-in-partner-hospital-application/
# ✅ Saved: articles\Netclan20241018.txt
# Scraping: https://insights.blackcoffer.com/roas-dashboard-for-campaign-wise-google-ads-budget-tracking-using-google-ads-ap/
# ✅ Saved: articles\Netclan20241019.txt
# Scraping: https://insights.blackcoffer.com/efficient-processing-and-analysis-of-financial-data-from-pdf-files-addressing-formatting-inconsistencies-and-ensuring-data-integrity-for-a-toyota-dealership-management-firm/
# ✅ Saved: articles\Netclan20241020.txt
# Scraping: https://insights.blackcoffer.com/development-of-ea-robot-for-automated-trading/
# ✅ Saved: articles\Netclan20241021.txt
# Scraping: https://insights.blackcoffer.com/ai-and-ml-based-youtube-analytics-and-content-creation-tool-for-optimizing-subscriber-engagement-and-content-strategy/
# ✅ Saved: articles\Netclan20241022.txt
# Scraping: https://insights.blackcoffer.com/enhancing-front-end-features-and-functionality-for-improved-user-experience-and-dashboard-accuracy-in-partner-hospital-application/
# ✅ Saved: articles\Netclan20241023.txt
# Scraping: https://insights.blackcoffer.com/roas-dashboard-for-campaign-wise-google-ads-budget-tracking-using-google-ads-ap/
# ✅ Saved: articles\Netclan20241024.txt
# Scraping: https://insights.blackcoffer.com/efficient-processing-and-analysis-of-financial-data-from-pdf-files-addressing-formatting-inconsistencies-and-ensuring-data-integrity-for-a-toyota-dealership-management-firm/
# ✅ Saved: articles\Netclan20241025.txt
# Scraping: https://insights.blackcoffer.com/transforming-and-managing-a-large-scale-sql-pedigree-database-to-neo4j-graph-db/
# ✅ Saved: articles\Netclan20241026.txt
# Scraping: https://insights.blackcoffer.com/enhancing-model-accuracy-from-58-to-over-90-strategies-for-improving-predictive-performance/
# ✅ Saved: articles\Netclan20241027.txt
# Scraping: https://insights.blackcoffer.com/securing-sensitive-financial-data-with-privacy-preserving-machine-learning-for-predictive-analytics/
# ✅ Saved: articles\Netclan20241028.txt
# Scraping: https://insights.blackcoffer.com/enhancing-data-collection-for-research-institutions-addressing-survey-fatigue-and-incorporating-verbal-communication-for-richer-insights/
# ✅ Saved: articles\Netclan20241029.txt
# Scraping: https://insights.blackcoffer.com/analyzing-the-impact-of-positive-emotions-and-pandemic-severity-on-mental-health-and-resilience-among-entrepreneurs-insights-and-predictive-modeling/
# ✅ Saved: articles\Netclan20241030.txt
# Scraping: https://insights.blackcoffer.com/dynamic-brand-centric-dashboard-for-automotive-dealerships-pdf-to-financial-insights-with-flask-react-architecture-and-aws-cloud-hosting/
# ✅ Saved: articles\Netclan20241031.txt
# Scraping: https://insights.blackcoffer.com/cloud-based-data-modeling-and-analysis-platform-with-drag-and-drop-interface-and-openai-api-integration-for-simulation-insights/
# ✅ Saved: articles\Netclan20241032.txt
# Scraping: https://insights.blackcoffer.com/voter-profile-analysis-and-search-application-for-targeted-campaign-engagement-using-government-voter-data/
# ✅ Saved: articles\Netclan20241033.txt
# Scraping: https://insights.blackcoffer.com/bert-based-classification-of-individuals-and-organizations-into-two-categories-using-natural-language-processing/
# ✅ Saved: articles\Netclan20241034.txt
# Scraping: https://insights.blackcoffer.com/comprehensive-analysis-of-solana-and-ethereum-contributors-using-github-api-with-comparative-study-of-1000-random-github-profiles/
# ✅ Saved: articles\Netclan20241035.txt
# Scraping: https://insights.blackcoffer.com/powerbi-rest-api-fetching-dataflow-and-refresh-schedules-with-semantic-models/
# ✅ Saved: articles\Netclan20241036.txt
# Scraping: https://insights.blackcoffer.com/automated-job-data-import-and-management-solution-for-enhanced-efficiency/
# ✅ Saved: articles\Netclan20241037.txt
# Scraping: https://insights.blackcoffer.com/data-analytics-and-optimization-solution-for-enhancing-renewable-energy-efficiency/
# ✅ Saved: articles\Netclan20241038.txt
# Scraping: https://insights.blackcoffer.com/time-series-analysis-and-trend-forecasting-solution-for-predicting-news-trends/
# ✅ Saved: articles\Netclan20241039.txt
# Scraping: https://insights.blackcoffer.com/advanced-data-visualization-solutions-for-monitoring-key-business-metrics-with-integrated-interactive-dashboards/
# ✅ Saved: articles\Netclan20241040.txt
# Scraping: https://insights.blackcoffer.com/advanced-patient-data-analysis-solution-for-trend-identification-and-improved-healthcare-outcome/
# ✅ Saved: articles\Netclan20241041.txt
# Scraping: https://insights.blackcoffer.com/anomaly-detection-and-analysis-for-enhanced-data-integrity-and-user-experience-on-bright-datas-website/
# ✅ Saved: articles\Netclan20241042.txt
# Scraping: https://insights.blackcoffer.com/building-custom-tflite-models-and-benchmarking-on-voxl2-chips/
# ✅ Saved: articles\Netclan20241043.txt
# Scraping: https://insights.blackcoffer.com/sports-prediction-model-for-multiple-sports-leagues/
# ✅ Saved: articles\Netclan20241044.txt
# Scraping: https://insights.blackcoffer.com/efficient-coach-allocation-system-for-sports-coaching-organization/
# ✅ Saved: articles\Netclan20241045.txt
# Scraping: https://insights.blackcoffer.com/data-studio-dashboard-with-a-data-pipeline-tool-synced-with-podio-using-custom-webhooks-and-google-cloud-function-2/
# ✅ Saved: articles\Netclan20241046.txt
# Scraping: https://insights.blackcoffer.com/ai-driven-backend-for-audio-to-text-conversion-and-analytical-assessment-in-pharmaceutical-practice/
# ✅ Saved: articles\Netclan20241047.txt
# Scraping: https://insights.blackcoffer.com/cloud-based-web-application-for-financial-data-processing-and-visualization-of-sp-500-metrics/
# ✅ Saved: articles\Netclan20241048.txt
# Scraping: https://insights.blackcoffer.com/department-wise-kpi-tracking-dashboard-with-technician-performance-analysis-for-atoz-dependable-service/
# ✅ Saved: articles\Netclan20241049.txt
# Scraping: https://insights.blackcoffer.com/steps-to-convert-a-node-js-api-to-python-for-aws-lambda-deployment/
# ✅ Saved: articles\Netclan20241050.txt
# Scraping: https://insights.blackcoffer.com/building-an-analytics-dashboard-with-a-pdf-parsing-pipeline-for-data-extraction/
# ✅ Saved: articles\Netclan20241051.txt
# Scraping: https://insights.blackcoffer.com/building-a-real-time-log-file-visualization-dashboard-in-kibana/
# ✅ Saved: articles\Netclan20241052.txt
# Scraping: https://insights.blackcoffer.com/analyzing-the-impact-of-female-ceo-appointments-on-company-stock-prices/
# ✅ Saved: articles\Netclan20241053.txt
# Scraping: https://insights.blackcoffer.com/ai-chatbot-using-llm-langchain-llama/
# ✅ Saved: articles\Netclan20241054.txt
# Scraping: https://insights.blackcoffer.com/healthcare-ai-chatbot-using-llama-llm-langchain/
# ✅ Saved: articles\Netclan20241055.txt
# Scraping: https://insights.blackcoffer.com/ai-bot-audio-to-audio/
# ✅ Saved: articles\Netclan20241056.txt
# Scraping: https://insights.blackcoffer.com/recommendation-engine-for-insurance-sector-to-expand-business-in-the-rural-area/
# ✅ Saved: articles\Netclan20241057.txt
# Scraping: https://insights.blackcoffer.com/data-from-crm-via-zapier-to-google-sheets-dynamic-to-powerbi/
# ✅ Saved: articles\Netclan20241058.txt
# Scraping: https://insights.blackcoffer.com/data-warehouse-to-google-data-studio-looker-dashboard/
# ✅ Saved: articles\Netclan20241059.txt
# Scraping: https://insights.blackcoffer.com/crm-monday-com-via-zapier-to-power-bi-dashboard/
# ✅ Saved: articles\Netclan20241060.txt
# Scraping: https://insights.blackcoffer.com/monday-com-to-kpi-dashboard-to-manage-view-and-generate-insights-from-the-crm-data/
# ✅ Saved: articles\Netclan20241061.txt
# Scraping: https://insights.blackcoffer.com/data-management-for-a-political-saas-application/
# ✅ Saved: articles\Netclan20241062.txt
# Scraping: https://insights.blackcoffer.com/google-lsa-ads-google-local-service-ads-etl-tools-and-dashboards/
# ✅ Saved: articles\Netclan20241063.txt
# Scraping: https://insights.blackcoffer.com/ad-networks-marketing-campaign-data-dashboard-in-looker-google-data-studio/
# ✅ Saved: articles\Netclan20241064.txt
# Scraping: https://insights.blackcoffer.com/analytical-solution-for-a-tech-firm/
# ✅ Saved: articles\Netclan20241065.txt
# Scraping: https://insights.blackcoffer.com/ai-solution-for-a-technology-information-and-internet-firm/
# ✅ Saved: articles\Netclan20241066.txt
# Scraping: https://insights.blackcoffer.com/ai-and-nlp-based-solutions-to-automate-data-discovery-for-venture-capital-and-private-equity-principals/
# ✅ Saved: articles\Netclan20241067.txt
# Scraping: https://insights.blackcoffer.com/an-etl-solution-for-an-internet-publishing-firm/
# ✅ Saved: articles\Netclan20241068.txt
# Scraping: https://insights.blackcoffer.com/ai-based-algorithmic-trading-bot-for-forex/
# ✅ Saved: articles\Netclan20241069.txt
# Scraping: https://insights.blackcoffer.com/equity-waterfalls-model-based-saas-application-for-real-estate-sector/
# ✅ Saved: articles\Netclan20241070.txt
# Scraping: https://insights.blackcoffer.com/ai-solutions-for-foreign-exchange-an-automated-algo-trading-tool/
# ✅ Saved: articles\Netclan20241071.txt
# Scraping: https://insights.blackcoffer.com/ai-agent-development-and-deployment-in-jina-ai/
# ✅ Saved: articles\Netclan20241072.txt
# Scraping: https://insights.blackcoffer.com/golden-record-a-knowledge-graph-database-approach-to-unfold-discovery-using-neo4j/
# ✅ Saved: articles\Netclan20241073.txt
# Scraping: https://insights.blackcoffer.com/advanced-ai-for-trading-automation/
# ✅ Saved: articles\Netclan20241074.txt
# Scraping: https://insights.blackcoffer.com/create-a-knowledge-graph-to-provide-real-time-analytics-recommendations-and-a-single-source-of-truth/
# ✅ Saved: articles\Netclan20241075.txt
# Scraping: https://insights.blackcoffer.com/advanced-ai-for-thermal-person-detection/
# ✅ Saved: articles\Netclan20241076.txt
# Scraping: https://insights.blackcoffer.com/advanced-ai-for-road-cam-threat-detection/
# ✅ Saved: articles\Netclan20241077.txt
# Scraping: https://insights.blackcoffer.com/advanced-ai-for-pedestrian-crossing-safety/
# ✅ Saved: articles\Netclan20241078.txt
# Scraping: https://insights.blackcoffer.com/handgun-detection-using-yolo/
# ✅ Saved: articles\Netclan20241079.txt
# Scraping: https://insights.blackcoffer.com/using-graph-technology-to-create-single-customer-view/
# ✅ Saved: articles\Netclan20241080.txt
# Scraping: https://insights.blackcoffer.com/car-detection-in-satellite-images/
# ✅ Saved: articles\Netclan20241081.txt
# Scraping: https://insights.blackcoffer.com/building-a-physics-informed-neural-network-for-circuit-evaluation/
# ✅ Saved: articles\Netclan20241082.txt
# Scraping: https://insights.blackcoffer.com/connecting-mongodb-database-to-power-bi-dashboard-dashboard-automation/
# ✅ Saved: articles\Netclan20241083.txt
# Scraping: https://insights.blackcoffer.com/data-transformation/
# ✅ Saved: articles\Netclan20241084.txt
# Scraping: https://insights.blackcoffer.com/e-commerce-store-analysis-purchase-behavior-ad-spend-conversion-traffic-etc/
# ✅ Saved: articles\Netclan20241085.txt
# Scraping: https://insights.blackcoffer.com/kpi-dashboard-for-accountants/
# ✅ Saved: articles\Netclan20241086.txt
# Scraping: https://insights.blackcoffer.com/return-on-advertising-spend-dashboard-marketing-automation-and-analytics-using-etl-and-dashboard/
# ✅ Saved: articles\Netclan20241087.txt
# Scraping: https://insights.blackcoffer.com/ranking-customer-behaviours-for-business-strategy/
# ✅ Saved: articles\Netclan20241088.txt
# Scraping: https://insights.blackcoffer.com/algorithmic-trading-for-multiple-commodities-markets-like-forex-metals-energy-etc/
# ✅ Saved: articles\Netclan20241089.txt
# Scraping: https://insights.blackcoffer.com/trading-bot-for-forex/
# ✅ Saved: articles\Netclan20241090.txt
# Scraping: https://insights.blackcoffer.com/python-model-for-the-analysis-of-sector-specific-stock-etfs-for-investment-purposes%ef%bf%bc/
# ✅ Saved: articles\Netclan20241091.txt
# Scraping: https://insights.blackcoffer.com/medical-classification/
# ✅ Saved: articles\Netclan20241092.txt
# Scraping: https://insights.blackcoffer.com/design-develop-bert-question-answering-model-explanations-with-visualization/
# ✅ Saved: articles\Netclan20241093.txt
# Scraping: https://insights.blackcoffer.com/design-and-develop-solution-to-anomaly-detection-classification-problems/
# ✅ Saved: articles\Netclan20241094.txt
# Scraping: https://insights.blackcoffer.com/an-etl-solution-for-currency-data-to-google-big-query/
# ✅ Saved: articles\Netclan20241095.txt
# Scraping: https://insights.blackcoffer.com/etl-and-mlops-infrastructure-for-blockchain-analytics/
# ✅ Saved: articles\Netclan20241096.txt
# Scraping: https://insights.blackcoffer.com/an-agent-based-model-of-a-virtual-power-plant-vpp/
# ✅ Saved: articles\Netclan20241097.txt
# Scraping: https://insights.blackcoffer.com/transform-api-into-sdk-library-and-widget/
# ✅ Saved: articles\Netclan20241098.txt
# Scraping: https://insights.blackcoffer.com/integration-of-a-product-to-a-cloud-based-crm-platform/
# ✅ Saved: articles\Netclan20241099.txt
# Scraping: https://insights.blackcoffer.com/a-web-based-dashboard-for-the-filtered-data-retrieval-of-land-records/
# ✅ Saved: articles\Netclan20241100.txt
# Scraping: https://insights.blackcoffer.com/integration-of-video-conferencing-data-to-the-existing-web-app/
# ✅ Saved: articles\Netclan20241101.txt
# Scraping: https://insights.blackcoffer.com/design-develop-an-app-in-retool-which-shows-the-progress-of-the-added-video/
# ✅ Saved: articles\Netclan20241102.txt
# Scraping: https://insights.blackcoffer.com/auvik-connectwise-integration-in-grafana/
# ✅ Saved: articles\Netclan20241103.txt
# Scraping: https://insights.blackcoffer.com/data-integration-and-big-data-performance-using-elk-stack/
# ✅ Saved: articles\Netclan20241104.txt
# Scraping: https://insights.blackcoffer.com/web-data-connector/
# ✅ Saved: articles\Netclan20241105.txt
# Scraping: https://insights.blackcoffer.com/an-app-for-updating-the-email-id-of-the-user-and-stripe-refund-tool-using-retool/
# ✅ Saved: articles\Netclan20241106.txt
# Scraping: https://insights.blackcoffer.com/an-ai-ml-based-web-application-that-detects-the-correctness-of-text-in-a-given-video/
# ✅ Saved: articles\Netclan20241107.txt
# Scraping: https://insights.blackcoffer.com/website-tracking-and-insights-using-google-analytics-google-tag-manager/
# ✅ Saved: articles\Netclan20241108.txt
# Scraping: https://insights.blackcoffer.com/dashboard-to-track-the-analytics-of-the-website-using-google-analytics-and-google-tag-manager/
# ✅ Saved: articles\Netclan20241109.txt
# Scraping: https://insights.blackcoffer.com/power-bi-dashboard-on-operations-transactions-and-marketing-embedding-the-dashboard-to-web-app/
# ✅ Saved: articles\Netclan20241110.txt
# Scraping: https://insights.blackcoffer.com/nft-data-automation-looksrare-and-etl-tool/
# ✅ Saved: articles\Netclan20241111.txt
# Scraping: https://insights.blackcoffer.com/optimize-the-data-scraper-program-to-easily-accommodate-large-files-and-solve-oom-errors/
# ✅ Saved: articles\Netclan20241112.txt
# Scraping: https://insights.blackcoffer.com/making-a-robust-way-to-sync-data-from-airtables-to-mongodb-using-python-etl-solution/
# ✅ Saved: articles\Netclan20241113.txt
# Scraping: https://insights.blackcoffer.com/incident-duration-prediction-infrastructure-and-real-estate/
# ✅ Saved: articles\Netclan20241114.txt
# Scraping: https://insights.blackcoffer.com/statistical-data-analysis-of-reinforced-concrete/
# ✅ Saved: articles\Netclan20241115.txt
# Scraping: https://insights.blackcoffer.com/database-normalization-segmentation-with-google-data-studio-dashboard-insights/
# ✅ Saved: articles\Netclan20241116.txt
# Scraping: https://insights.blackcoffer.com/power-bi-dashboard-to-drive-insights-from-complex-data-to-generate-business-insights/
# ✅ Saved: articles\Netclan20241117.txt
# Scraping: https://insights.blackcoffer.com/real-time-dashboard-to-monitor-infrastructure-activity-and-machines/
# ✅ Saved: articles\Netclan20241118.txt
# Scraping: https://insights.blackcoffer.com/electric-vehicles-ev-load-management-system-to-forecast-energy-demand/
# ✅ Saved: articles\Netclan20241119.txt
# Scraping: https://insights.blackcoffer.com/power-bi-data-driven-map-dashboard/
# ✅ Saved: articles\Netclan20241120.txt
# Scraping: https://insights.blackcoffer.com/google-local-service-ads-lsa-leads-dashboard/
# ✅ Saved: articles\Netclan20241121.txt
# Scraping: https://insights.blackcoffer.com/aws-lex-voice-and-chatbot/
# ✅ Saved: articles\Netclan20241122.txt
# Scraping: https://insights.blackcoffer.com/metabridges-api-decentraland-integration/
# ✅ Saved: articles\Netclan20241123.txt
# Scraping: https://insights.blackcoffer.com/microsoft-azure-chatbot-with-luis-language-understanding/
# ✅ Saved: articles\Netclan20241124.txt
# Scraping: https://insights.blackcoffer.com/impact-of-news-media-and-press-on-innovation-startups-and-investments/
# ✅ Saved: articles\Netclan20241125.txt
# Scraping: https://insights.blackcoffer.com/aws-quicksight-reporting-dashboard/
# ✅ Saved: articles\Netclan20241126.txt
# Scraping: https://insights.blackcoffer.com/google-data-studio-dashboard-for-marketing-ads-and-traction-data/
# ✅ Saved: articles\Netclan20241127.txt
# Scraping: https://insights.blackcoffer.com/gangala-in-e-commerce-big-data-etl-elt-solution-and-data-warehouse/
# ✅ Saved: articles\Netclan20241128.txt
# Scraping: https://insights.blackcoffer.com/big-data-solution-to-an-online-multivendor-marketplace-ecommerce-business/
# ✅ Saved: articles\Netclan20241129.txt
# Scraping: https://insights.blackcoffer.com/creating-a-custom-report-and-dashboard-using-the-data-got-from-atera-api/
# ✅ Saved: articles\Netclan20241130.txt
# Scraping: https://insights.blackcoffer.com/azure-data-lake-and-power-bi-dashboard/
# ✅ Saved: articles\Netclan20241131.txt
# Scraping: https://insights.blackcoffer.com/google-data-studio-pipeline-with-gcp-mysql/
# ✅ Saved: articles\Netclan20241132.txt
# Scraping: https://insights.blackcoffer.com/quickbooks-dashboard-to-find-patterns-in-finance-sales-and-forecasts/
# ✅ Saved: articles\Netclan20241133.txt
# Scraping: https://insights.blackcoffer.com/marketing-sales-and-financial-data-business-dashboard-wink-report/
# ✅ Saved: articles\Netclan20241134.txt
# Scraping: https://insights.blackcoffer.com/react-native-apps-in-the-development-portfolio/
# ✅ Saved: articles\Netclan20241135.txt
# Scraping: https://insights.blackcoffer.com/a-leading-firm-website-seo-optimization/
# ✅ Saved: articles\Netclan20241136.txt
# Scraping: https://insights.blackcoffer.com/a-leading-hospitality-firm-in-the-usa-website-seo-optimization/
# ✅ Saved: articles\Netclan20241137.txt
# Scraping: https://insights.blackcoffer.com/a-leading-firm-in-the-usa-website-seo-optimization/
# ✅ Saved: articles\Netclan20241138.txt
# Scraping: https://insights.blackcoffer.com/a-leading-musical-instrumental-website-seo-optimization/
# ✅ Saved: articles\Netclan20241139.txt
# Scraping: https://insights.blackcoffer.com/a-leading-firm-in-the-usa-seo-and-website-optimization/
# ✅ Saved: articles\Netclan20241140.txt
# Scraping: https://insights.blackcoffer.com/immigration-datawarehouse-ai-based-recommendations/
# ✅ Saved: articles\Netclan20241141.txt
# Scraping: https://insights.blackcoffer.com/lipsync-automation-for-celebrities-and-influencers/
# ✅ Saved: articles\Netclan20241142.txt
# Scraping: https://insights.blackcoffer.com/key-audit-matters-predictive-modeling/
# ✅ Saved: articles\Netclan20241143.txt
# Scraping: https://insights.blackcoffer.com/splitting-of-songs-into-its-vocals-and-instrumental/
# ✅ Saved: articles\Netclan20241144.txt
# Scraping: https://insights.blackcoffer.com/ai-and-ml-technologies-to-evaluate-learning-assessments/
# ✅ Saved: articles\Netclan20241145.txt
# Scraping: https://insights.blackcoffer.com/datawarehouse-and-recommendations-engine-for-airbnb/
# ✅ Saved: articles\Netclan20241146.txt
# Scraping: https://insights.blackcoffer.com/real-estate-data-warehouse/
# ✅ Saved: articles\Netclan20241147.txt
# Scraping: https://insights.blackcoffer.com/traction-dashboards-of-marketing-campaigns-and-posts/
# ✅ Saved: articles\Netclan20241148.txt
# Scraping: https://insights.blackcoffer.com/google-local-service-ads-lsa-data-warehouse/
# ✅ Saved: articles\Netclan20241149.txt
# Scraping: https://insights.blackcoffer.com/google-local-service-ads-missed-calls-and-messages-automation-tool/
# ✅ Saved: articles\Netclan20241150.txt
# Scraping: https://insights.blackcoffer.com/marketing-ads-leads-call-status-data-tool-to-bigquery/
# ✅ Saved: articles\Netclan20241151.txt
# Scraping: https://insights.blackcoffer.com/marketing-analytics-to-automate-leads-call-status-and-reporting/
# ✅ Saved: articles\Netclan20241152.txt
# Scraping: https://insights.blackcoffer.com/callrail-analytics-leads-report-alert/
# ✅ Saved: articles\Netclan20241153.txt
# Scraping: https://insights.blackcoffer.com/marketing-automation-tool-to-notify-lead-details-to-clients-over-email-and-phone/
# ✅ Saved: articles\Netclan20241154.txt
# Scraping: https://insights.blackcoffer.com/data-etl-local-service-ads-leads-to-bigquery/
# ✅ Saved: articles\Netclan20241155.txt
# Scraping: https://insights.blackcoffer.com/marbles-stimulation-using-python/
# ✅ Saved: articles\Netclan20241156.txt
# Scraping: https://insights.blackcoffer.com/stocktwits-data-structurization/
# ✅ Saved: articles\Netclan20241157.txt
# Scraping: https://insights.blackcoffer.com/sentimental-analysis-on-shareholder-letter-of-companies/
# ✅ Saved: articles\Netclan20241158.txt
# Scraping: https://insights.blackcoffer.com/population-and-community-survey-of-america/
# ✅ Saved: articles\Netclan20241159.txt
# Scraping: https://insights.blackcoffer.com/google-lsa-api-data-automation-and-dashboarding/
# ✅ Saved: articles\Netclan20241160.txt
# Scraping: https://insights.blackcoffer.com/healthcare-data-analysis/
# ✅ Saved: articles\Netclan20241161.txt
# Scraping: https://insights.blackcoffer.com/budget-sales-kpi-dashboard-using-power-bi/
# ✅ Saved: articles\Netclan20241162.txt
# Scraping: https://insights.blackcoffer.com/amazon-buy-bot-an-automation-ai-tool-to-auto-checkouts/
# ✅ Saved: articles\Netclan20241163.txt

# %%
pip install pandas numpy xlsxwriter openpyxl
# Out:
# Requirement already satisfied: pandas in c:\users\sansk\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy in c:\users\sansk\anaconda3\lib\site-packages (1.26.4)
# Collecting xlsxwriter
#   Downloading xlsxwriter-3.2.5-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: openpyxl in c:\users\sansk\anaconda3\lib\site-packages (3.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sansk\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sansk\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sansk\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: et-xmlfile in c:\users\sansk\anaconda3\lib\site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\sansk\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading xlsxwriter-3.2.5-py3-none-any.whl (172 kB)
# Installing collected packages: xlsxwriter
# Successfully installed xlsxwriter-3.2.5
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import re
import pandas as pd
import numpy as np

# ======================
# 1️⃣ READ INPUT EXCEL
# ======================
input_excel = "Input.xlsx"   # Make sure Input.xlsx is in same folder
df_input = pd.read_excel(input_excel)

# ======================
# 2️⃣ SENTIMENT WORD LISTS (can be extended)
# ======================
# Replace with larger lexicon lists if available
positive_words = ["good", "great", "excellent", "positive", "fortunate", "correct", "superior", "happy", "benefit", "success"]
negative_words = ["bad", "terrible", "poor", "negative", "unfortunate", "wrong", "inferior", "sad", "problem", "failure"]

# ======================
# 3️⃣ HELPER FUNCTIONS
# ======================

def count_syllables(word):
    """Estimate syllables in a word (basic heuristic)."""
    word = word.lower()
    vowels = "aeiou"
    count = 0
    prev_char_was_vowel = False
    for char in word:
        if char in vowels:
            if not prev_char_was_vowel:
                count += 1
            prev_char_was_vowel = True
        else:
            prev_char_was_vowel = False
    if word.endswith("e"):
        count = max(1, count-1)
    return count if count > 0 else 1

def is_complex_word(word):
    """A complex word has 3 or more syllables."""
    return count_syllables(word) >= 3

def analyze_text(text):
    """Perform text analysis and return metrics as a dictionary."""

    # Sentence and word tokenization
    sentences = re.split(r'[.!?]+', text)
    sentences = [s.strip() for s in sentences if s.strip()]

    words = re.findall(r'\b[a-zA-Z]+\b', text)
    words_lower = [w.lower() for w in words]

    word_count = len(words)
    sentence_count = len(sentences) if sentences else 1  # prevent divide by zero

    # Sentiment scores
    pos_score = sum(1 for w in words_lower if w in positive_words)
    neg_score = sum(1 for w in words_lower if w in negative_words)
    polarity = (pos_score - neg_score) / ((pos_score + neg_score) + 1e-6)
    subjectivity = (pos_score + neg_score) / (word_count + 1e-6)

    # Complexity metrics
    complex_words = [w for w in words if is_complex_word(w)]
    complex_word_count = len(complex_words)
    avg_sentence_length = word_count / sentence_count
    pct_complex_words = complex_word_count / word_count if word_count else 0
    fog_index = 0.4 * (avg_sentence_length + pct_complex_words * 100)

    # Other metrics
    syllable_per_word = np.mean([count_syllables(w) for w in words]) if words else 0
    personal_pronouns = len(re.findall(r"\b(I|we|my|ours|us)\b", text, flags=re.I))
    avg_word_length = np.mean([len(w) for w in words]) if words else 0

    return {
        "POSITIVE SCORE": pos_score,
        "NEGATIVE SCORE": neg_score,
        "POLARITY SCORE": polarity,
        "SUBJECTIVITY SCORE": subjectivity,
        "AVG SENTENCE LENGTH": avg_sentence_length,
        "PERCENTAGE OF COMPLEX WORDS": pct_complex_words,
        "FOG INDEX": fog_index,
        "AVG NUMBER OF WORDS PER SENTENCE": avg_sentence_length,
        "COMPLEX WORD COUNT": complex_word_count,
        "WORD COUNT": word_count,
        "SYLLABLE PER WORD": syllable_per_word,
        "PERSONAL PRONOUNS": personal_pronouns,
        "AVG WORD LENGTH": avg_word_length
    }

# ======================
# 4️⃣ PROCESS ARTICLES
# ======================
output_data = []

for _, row in df_input.iterrows():
    url_id = row["URL_ID"]
    url = row["URL"]
    file_path = os.path.join("articles", f"{url_id}.txt")

    if not os.path.exists(file_path):
        print(f"⚠️ Missing file for {url_id}")
        continue

    with open(file_path, "r", encoding="utf-8") as f:
        text = f.read()

    metrics = analyze_text(text)
    metrics["URL_ID"] = url_id
    metrics["URL"] = url
    output_data.append(metrics)

# ======================
# 5️⃣ CREATE FINAL DATAFRAME IN CORRECT ORDER
# ======================
output_df = pd.DataFrame(output_data)

final_columns = [
    "URL_ID", "URL",
    "POSITIVE SCORE", "NEGATIVE SCORE", "POLARITY SCORE", "SUBJECTIVITY SCORE",
    "AVG SENTENCE LENGTH", "PERCENTAGE OF COMPLEX WORDS", "FOG INDEX",
    "AVG NUMBER OF WORDS PER SENTENCE", "COMPLEX WORD COUNT", "WORD COUNT",
    "SYLLABLE PER WORD", "PERSONAL PRONOUNS", "AVG WORD LENGTH"
]

output_df = output_df[final_columns]

# ======================
# 6️⃣ SAVE TO UTF‑8 EXCEL FILE
# ======================
output_file = "Final_Output.xlsx"

with pd.ExcelWriter(output_file, engine='xlsxwriter') as writer:
    output_df.to_excel(writer, index=False, sheet_name='Sheet1')
    # prevent Excel auto-converting strings to hyperlinks
    workbook  = writer.book
    worksheet = writer.sheets['Sheet1']
    for col_num, value in enumerate(output_df.columns.values):
        worksheet.write(0, col_num, value)

# %%
import os
import re
import pandas as pd
import numpy as np

# ===========================
# 1️⃣ HELPER FUNCTIONS
# ===========================

def clean_text(text, stopwords=None):
    """Remove stopwords and tokenize text into words"""
    words = re.findall(r'\b[a-zA-Z]+\b', text)
    if stopwords:
        words = [w for w in words if w.lower() not in stopwords]
    return words

def count_syllables(word):
    """Count syllables in a word based on vowels with adjustments for 'es'/'ed' endings"""
    word = word.lower()
    vowels = "aeiou"
    count = 0
    prev_char_was_vowel = False
    for char in word:
        if char in vowels:
            if not prev_char_was_vowel:
                count += 1
            prev_char_was_vowel = True
        else:
            prev_char_was_vowel = False
    # Adjust for endings
    if word.endswith(("es","ed","e")):
        count = max(1, count-1)
    return count if count > 0 else 1

def is_complex_word(word):
    """A complex word has 3 or more syllables"""
    return count_syllables(word) >= 3

def analyze_text(text, positive_words, negative_words, stopwords=None):
    """Compute all metrics from Text Analysis.docx"""

    # ========= CLEAN TEXT =========
    words = clean_text(text, stopwords)
    word_count = len(words)

    # ========= SENTENCES =========
    sentences = re.split(r'[.!?]+', text)
    sentences = [s.strip() for s in sentences if s.strip()]
    sentence_count = len(sentences) if sentences else 1

    # ========= SENTIMENT SCORES =========
    pos_score = sum(1 for w in words if w.lower() in positive_words)
    neg_score = sum(1 for w in words if w.lower() in negative_words)

    polarity = (pos_score - neg_score) / ((pos_score + neg_score) + 0.000001)
    subjectivity = (pos_score + neg_score) / (word_count + 0.000001)

    # ========= READABILITY =========
    avg_sentence_length = word_count / sentence_count
    complex_word_count = sum(1 for w in words if is_complex_word(w))
    pct_complex_words = complex_word_count / word_count if word_count else 0
    fog_index = 0.4 * (avg_sentence_length + (pct_complex_words * 100))

    # ========= OTHER METRICS =========
    syllable_per_word = np.mean([count_syllables(w) for w in words]) if words else 0
    personal_pronouns = len(re.findall(r"\b(I|we|my|ours|us)\b", text, flags=re.I))
    avg_word_length = np.mean([len(w) for w in words]) if words else 0

    return {
        "POSITIVE SCORE": pos_score,
        "NEGATIVE SCORE": neg_score,
        "POLARITY SCORE": polarity,
        "SUBJECTIVITY SCORE": subjectivity,
        "AVG SENTENCE LENGTH": avg_sentence_length,
        "PERCENTAGE OF COMPLEX WORDS": pct_complex_words,
        "FOG INDEX": fog_index,
        "AVG NUMBER OF WORDS PER SENTENCE": avg_sentence_length,
        "COMPLEX WORD COUNT": complex_word_count,
        "WORD COUNT": word_count,
        "SYLLABLE PER WORD": syllable_per_word,
        "PERSONAL PRONOUNS": personal_pronouns,
        "AVG WORD LENGTH": avg_word_length
    }

# ===========================
# 2️⃣ LOAD INPUT & STOPWORDS
# ===========================

input_excel = "Input.xlsx"
df_input = pd.read_excel(input_excel)

# Load stopwords from provided files
stopword_files = ["StopWords_Currencies.txt", "StopWords_Auditor.txt", "StopWords_DatesandNumbers.txt"]
stopwords = set()

for file in stopword_files:
    if os.path.exists(file):
        with open(file, "r", encoding="utf-8") as f:
            for line in f:
                word = line.strip().split('|')[0].strip()
                if word:
                    stopwords.add(word.lower())

# ===========================
# 3️⃣ SENTIMENT WORD LISTS
# (Replace with MasterDictionary if available)
# ===========================
positive_words = {"good","great","excellent","positive","fortunate","correct","superior","happy","benefit","success"}
negative_words = {"bad","terrible","poor","negative","unfortunate","wrong","inferior","sad","problem","failure"}

# ===========================
# 4️⃣ ANALYZE EACH ARTICLE
# ===========================
output_data = []

for _, row in df_input.iterrows():
    url_id = row["URL_ID"]
    url = row["URL"]
    file_path = os.path.join("articles", f"{url_id}.txt")

    if not os.path.exists(file_path):
        print(f"⚠️ Missing file for {url_id}")
        continue

    with open(file_path, "r", encoding="utf-8") as f:
        text = f.read()

    metrics = analyze_text(text, positive_words, negative_words, stopwords)
    metrics["URL_ID"] = url_id
    metrics["URL"] = url
    output_data.append(metrics)

# ===========================
# 5️⃣ CREATE DATAFRAME
# ===========================
output_df = pd.DataFrame(output_data)

final_columns = [
    "URL_ID", "URL",
    "POSITIVE SCORE", "NEGATIVE SCORE", "POLARITY SCORE", "SUBJECTIVITY SCORE",
    "AVG SENTENCE LENGTH", "PERCENTAGE OF COMPLEX WORDS", "FOG INDEX",
    "AVG NUMBER OF WORDS PER SENTENCE", "COMPLEX WORD COUNT", "WORD COUNT",
    "SYLLABLE PER WORD", "PERSONAL PRONOUNS", "AVG WORD LENGTH"
]

output_df = output_df[final_columns]

# ===========================
# 6️⃣ SAVE TO EXCEL + UTF‑8 CSV
# ===========================
excel_file = "Final_Output.xlsx"
csv_file = "Final_Output_UTF8.csv"

output_df.to_excel(excel_file, index=False, engine='xlsxwriter')
output_df.to_csv(csv_file, index=False, encoding='utf-8-sig')

print("✅ Final_Output.xlsx & Final_Output_UTF8.csv created successfully!")
# Out:
# ✅ Final_Output.xlsx & Final_Output_UTF8.csv created successfully!
